# %%
import qiskit

# %%
qiskit.__version__
# Out:
# '0.16.4'

# %%
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.16.4',
#  'qiskit-aer': '0.7.6',
#  'qiskit-ignis': '0.5.2',
#  'qiskit-ibmq-provider': '0.12.1',
#  'qiskit-aqua': '0.8.2',
#  'qiskit': '0.24.0'}

# %%
API_TOKEN =  'b500ec3de41f1232493f18d76977f689b861c20693488af77fd024730becfcc7cac8bf0bde0dbc86b8cbf5e0c796f15745afc7905862da0f664ce055e9da5b7e'
from qiskit import IBMQ
IBMQ.save_account('MY_API_TOKEN',overwrite=True)

# %%
from qiskit import(QuantumCircuit,execute,Aer)
import numpy as np
from qiskit.visualization import plot_histogram
simulator = Aer.get_backend('qasm_simulator')
circuit = QuantumCircuit(2,2)
circuit.h(0)
circuit.cx(0,1)
circuit.measure([0,1],[0,1])
job = execute(circuit,simulator,shots=1000000);
result = job.result()
counts = result.get_counts(circuit)
print("\nTotal count for 00 and 11 are:",counts)

# Draw the circuit
circuit.draw()
# Out:
# Total count for 00 and 11 are: {'00': 499261, '11': 500739}
#      ┌───┐     ┌─┐
# q_0: ┤ H ├──■──┤M├───
#      └───┘┌─┴─┐└╥┘┌─┐
# q_1: ─────┤ X ├─╫─┤M├
#           └───┘ ║ └╥┘
# c: 2/═══════════╩══╩═
#                 0  1

# %%
plot_histogram(counts)
